# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# !mkdir Yolo
# %cd /content/drive/MyDrive/Colab Notebooks/Yolo
# !mkdir Pretrain

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Yolo/Pretrain
# !wget install https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8x.pt

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Yolo
# !rm mydataset.yaml
# !echo "path: /content/drive/MyDrive/Colab Notebooks/Yolo/train" >> mydataset.yaml
# !echo "train: /content/drive/MyDrive/Colab Notebooks/Yolo/train/images" >> mydataset.yaml
# !echo "val: /content/drive/MyDrive/Colab Notebooks/Yolo/train/images" >> mydataset.yaml
# !echo "nc: 1" >> mydataset.yaml
# !echo "names: ['Thang']" >> mydataset.yaml

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# Load a pretrained YOLO model (recommended for training)
model = YOLO('/content/drive/MyDrive/Colab Notebooks/Yolo/Pretrain/yolov8n-face.pt')
model.conf = 0.5
# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data='/content/drive/MyDrive/Colab Notebooks/Yolo/mydataset.yaml', epochs=100, batch=4)
# Out:
# WARNING ⚠️ /content/drive/MyDrive/Colab Notebooks/Yolo/Pretrain/yolov8n-face.pt appears to require 'omegaconf', which is not in ultralytics requirements.
# AutoInstall will run now for 'omegaconf' but this feature will be removed in the future.
# Recommend fixes are to train a new model using the latest 'ultralytics' package or to run a command with an official YOLOv8 model, i.e. 'yolo predict model=yolov8n.pt'
# requirements: Ultralytics requirement ['omegaconf'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 13.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=39a1842d2ec94e422fb818bef7e6c44733139e0bbcea80c8b117be96e251c942
# ...
